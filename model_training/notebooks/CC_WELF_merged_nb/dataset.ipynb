# %%
import pandas as pd

# %%
df = pd.read_csv("../../datasets/CC_WELF_merged_cleaned.csv")

# %%
len(df)
# Out:
# 144298

# %%
df['category'].value_counts()
# Out:
# category
# POLITICS              58065
# WORLDPOST             15358
# ENTERTAINMENT          9828
# WELLNESS & HEALTH      8344
# SPORTS                 7466
# BUSINESS               6185
# WORLD NEWS             5355
# TRAVEL                 3340
# MINORITY VOICES        3304
# CRIME                  3209
# ENVIRONMENT            2829
# ARTS & CULTURE         2757
# FOOD & DRINK           2421
# MEDIA                  2244
# PARENTING              1957
# TECH                   1784
# COMEDY                 1777
# SCIENCE                1261
# RELIGION               1131
# IMPACT & GOOD NEWS     1126
# STYLE & BEAUTY         1099
# EDUCATION               850
# WOMEN & FIFTY           785
# MONEY                   613
# WEIRD NEWS              448
# HOME & LIVING           376
# WEDDINGS                146
# U.S. NEWS               131
# DIVORCE                 109
# Name: count, dtype: int64

# %%
df_cc = pd.read_csv("../../datasets/Combined_Corpus/All_cleaned.csv")
df_cc['category'].value_counts(normalize=True)
# Out:
# category
# POLITICS              0.286572
# ENTERTAINMENT         0.091369
# WORLDPOST             0.087839
# WELLNESS & HEALTH     0.084848
# SPORTS                0.079418
# BUSINESS              0.060455
# TRAVEL                0.032626
# ARTS & CULTURE        0.029330
# ENVIRONMENT           0.026844
# CRIME                 0.025038
# FOOD & DRINK          0.023115
# MINORITY VOICES       0.021285
# PARENTING             0.019057
# WORLD NEWS            0.017450
# TECH                  0.016676
# MEDIA                 0.013451
# COMEDY                0.011833
# SCIENCE               0.011716
# IMPACT & GOOD NEWS    0.011118
# STYLE & BEAUTY        0.010578
# RELIGION              0.007881
# EDUCATION             0.007588
# MONEY                 0.006438
# WOMEN & FIFTY         0.005993
# WEIRD NEWS            0.004163
# HOME & LIVING         0.003870
# WEDDINGS              0.001372
# DIVORCE               0.001114
# U.S. NEWS             0.000962
# ...

# %%
#print sample of category = WORLDPOST
df_cc[df_cc['category'] == 'WORLDPOST'].sample(10)
# Out:
#                                                     text  label language  \
# 286    The militaries of the 30 countries that provid...      1       en
# 38590  With Israel's construction freeze on Jewish se...      1       en
# 2966   Britainâ€™s political leadership has frayed at...      1       en
# 13179  Argentinaâ€™s government welcomed on Monday a ...      1       en
# 21865  KSA Responds To Houthi Invasion By Bombing Sau...      0       en
# 57489  WASHINGTON â€” Britainâ€™s vote to leave the E...      1       en
# 5166   The head of the UN agency for Palestinian refu...      1       en
# 1872   As the world comes to terms with the biggest p...      1       en
# 6380   KARAK, Jordan â€” Gunmen involved in a rare te...      1       en
# 29020  A new political party in Guinea said Saturday ...      1       en
#
#         category
# 286    WORLDPOST
# 38590  WORLDPOST
# 2966   WORLDPOST
# 13179  WORLDPOST
# 21865  WORLDPOST
# 57489  WORLDPOST
# 5166   WORLDPOST
# ...

# %%
df_wf = pd.read_csv("../../datasets/WELFake_cleaned.csv")
df_wf['category'].value_counts(normalize=True)
# Out:
# category
# POLITICS              0.566189
# WORLDPOST             0.132181
# WORLD NEWS            0.064266
# ENTERTAINMENT         0.035214
# MINORITY VOICES       0.025125
# WELLNESS & HEALTH     0.019538
# CRIME                 0.018552
# MEDIA                 0.018536
# BUSINESS              0.018141
# COMEDY                0.012702
# SPORTS                0.012193
# TRAVEL                0.009958
# ENVIRONMENT           0.009481
# FOOD & DRINK          0.008068
# RELIGION              0.007772
# TECH                  0.006556
# PARENTING             0.005751
# ARTS & CULTURE        0.004930
# WOMEN & FIFTY         0.004798
# SCIENCE               0.004667
# STYLE & BEAUTY        0.003566
# EDUCATION             0.003500
# IMPACT & GOOD NEWS    0.003106
# WEIRD NEWS            0.001528
# MONEY                 0.001232
# U.S. NEWS             0.000871
# HOME & LIVING         0.000805
# WEDDINGS              0.000526
# DIVORCE               0.000246
# ...

# %%
df_wf[df_cc['category'] == 'WORLDPOST'].sample(10)
# Out:
# /tmp/ipykernel_47084/522318817.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_wf[df_cc['category'] == 'WORLDPOST'].sample(10)
#        Unnamed: 0                                              title  \
# 57810       67987  Libyans flee by boat amid 'terrible' violence ...
# 6307         6529  Today’s Upside Move In Gold & Silver Is Nothin...
# 55301       64641   BUSTED: Trump’s RNC Czar Caught Telling Party...
# 11100       11637  MELANIA TRUMP GIVES POWERFUL SPEECH to Honor ‘...
# 38409       43011  These Celebrities Just Made An Anti-Trump Vide...
# 18440       19692  Twitter employee briefly shuts Trump account, ...
# 40632       45747  John Bolton: Trump’s Only Mistake Was Not Firi...
# 19799       21187                  Demonic Possession Today (Part 1)
# 34580       38408   Stephen Colbert SCORCHES Jeff Sessions’ Racis...
# 41582       46955  Опрос: Россияне одобряют действия президента П...
#
# ...
