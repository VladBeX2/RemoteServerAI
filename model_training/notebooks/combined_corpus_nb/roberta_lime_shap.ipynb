# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv('roberta_test_predictions.csv')

# %%
len(df)
# Out:
# 16502

# %%
df.sample(10)
# Out:
#                                                     text  true_label  \
# 13570  the snowy landscape of the putoransky state na...           1
# 2143   texas prepares to secede from the united state...           0
# 9617   times insider shares insights into how we work...           1
# 3723   weaTMve had a tutorial on worry this year. the...           1
# 1025   obama caught in massive irs scandal facing maj...           0
# 7047   north arlington, n. j. a college roller hockey...           1
# 16367  cannabis juice company gets around dc lawby br...           0
# 12724  students protest school reeducation policies, ...           0
# 4305   a group of 10 conservative mps has written to ...           1
# 551    noting that the chances of one reaching the pl...           0
#
#        predicted_label  confidence_score
# 13570                1          0.999978
# 2143                 0          0.999867
# 9617                 1          0.999980
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df["confidence_score"], bins=200, edgecolor='black', alpha=0.7)
plt.xlabel("Confidence Score")
plt.ylabel("Number of Records")
plt.title("Distribution of Confidence Scores")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
y_true = df["true_label"]
y_pred = df["predicted_label"]

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print(f"Acuratețe: {accuracy:.4f}")
print(f"Precizie: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Acuratețe: 0.9996
# Precizie: 0.9999
# Recall: 0.9994
# F1-score: 0.9997

# %%
incorrect_predictions = df[df["true_label"] != df["predicted_label"]]

num_incorrect = len(incorrect_predictions)
print(f"Numărul de predicții greșite: {num_incorrect}")

print(incorrect_predictions.head(10))
# Out:
# Numărul de predicții greșite: 36
#                                                    text  true_label  \
# 399   decades after homosexuality was decriminalized...           1
# 507   the hawaii team, known for its powerful lineup...           0
# 1837  instead of using insecticides, a village in po...           1
# 2656  in a sharply critical op-ed piece for the russ...           0
# 3771  the condemnation of remarks by the los angeles...           1
# 4256  yesterday mayor hallinan announced a new beaut...           0
# 4375  these scenes, photographed with a smartphone a...           1
# 4395  the nominees for the 81st annual academy award...           0
# 4799  the lakers are dealing with another distractio...           0
# 4891  speaking of the supreme court, the loop 2009 l...           1
#
#       predicted_label
# 399                 0
# 507                 1
# 1837                0
# 2656                1
# 3771                0
# 4256                1
# ...
