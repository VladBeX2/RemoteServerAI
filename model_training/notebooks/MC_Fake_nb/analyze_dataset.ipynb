# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../datasets/MC_Fake_dataset.csv')

# %%
len(df)
# Out:
# 28133

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.sample(5)
#
# File ~/miniconda3/envs/proiect_env/lib/python3.9/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/miniconda3/envs/proiect_env/lib/python3.9/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# ...

# %%
#histogram for number of words in text 
df['text'].str.split().str.len().hist(bins=50)
import matplotlib.pyplot as plt
plt.xlabel('Number of words in text')
plt.ylabel('Frequency')
plt.title('Histogram of number of words in text')
plt.show()

# %%
# distribution of labels
df['labels'].value_counts().plot(kind='bar')
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Distribution of labels')
plt.show()

# %%
#how many nans in the dataset
df.isna().sum()
# Out:
# news_id                  0
# title                    0
# url                   6661
# publish_date         10401
# source               14393
# text                     0
# label                    0
# n_tweets                 0
# n_retweets               0
# n_replies                0
# n_users                  0
# tweet_ids                7
# retweet_ids           3366
# reply_ids             9104
# user_ids                 0
# retweet_relations     3455
# reply_relations       9163
# data_name                0
# language                 0
# category                 0
# dtype: int64

# %%
len(df)
# Out:
# 28335

# %%
# avg number of words in text
df['text'].str.split().str.len().mean()
# Out:
# 578.0460313510823

# %%
#how many labels are 0 
df['labels'].value_counts()[1]
# Out:
# 4439
