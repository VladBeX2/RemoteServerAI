# %% [markdown]
# # Analizam si curatam datasetul

# %%
import pandas as pd
import glob
import os

# %%
input_dir = "../../datasets/Article_category" 

csv_files = glob.glob(os.path.join(input_dir, "*.csv"))
print(f"Număr fișiere CSV găsite: {len(csv_files)}")
# Out:
# Număr fișiere CSV găsite: 210

# %%
df_list = []
for file in csv_files:
    try:
        df = pd.read_csv(file, on_bad_lines='skip', engine='python')
        df_list.append(df)
    except Exception as e:
        print(f"Eroare la citirea fișierului {file}: {e}")

df_all = pd.concat(df_list, ignore_index=True)
print(f"Număr total de articole combinate: {len(df_all)}")
# Out:
# Număr total de articole combinate: 22154527

# %%
print("Numarul de valori lipsa in df_all:", df_all.isnull().sum())
# Out:
# Numarul de valori lipsa in df_all: category           0
# content     17512337
# dtype: int64

# %%
df_all.sample(5)
# Out:
#                 category                                            content
# 11035540        POLITICS  Former U.S. Ambassador to the United Nations J...
# 6048256    ENTERTAINMENT                                                NaN
# 21414552        POLITICS  LOADING ERROR LOADING\n\nPresident Donald Trum...
# 21152908        POLITICS                                                NaN
# 19112368  HEALTHY LIVING                                                NaN

# %%
df_filtered = df_all.dropna(subset=["content"])

output_file = os.path.join(input_dir, "news_categories_filtered.csv")
df_filtered.to_csv(output_file, index=False)

print(f"Număr total de articole după filtrare: {len(df_filtered)}")
print(f"Fișier salvat: {output_file}")
# Out:
# Număr total de articole după filtrare: 4642190
# Fișier salvat: ../../datasets/Article_category/news_categories_filtered.csv

# %%
df_all.value_counts("category")
# Out:
# category
# POLITICS          5533579
# ENTERTAINMENT     2401269
# HEALTHY LIVING     843469
# QUEER VOICES       780558
# WELLNESS           737241
# COMEDY             673453
# WORLD NEWS         638092
# SPORTS             630015
# BLACK VOICES       600922
# BUSINESS           587022
# TRAVEL             568384
# THE WORLDPOST      558879
# PARENTS            532931
# WOMEN              498710
# CRIME              443558
# MEDIA              421680
# WEIRD NEWS         398589
# PARENTING          380270
# STYLE & BEAUTY     353212
# IMPACT             351663
# GREEN              332289
# RELIGION           315650
# FOOD & DRINK       297330
# STYLE              295600
# U.S. NEWS          283349
# TASTE              274423
# WORLDPOST          264849
# TECH               208241
# ARTS & CULTURE     208126
# SCIENCE            205477
# HOME & LIVING      186096
# GOOD NEWS          172861
# LATINO VOICES      165007
# ARTS               150520
# FIFTY              145212
# WEDDINGS           138992
# DIVORCE            136440
# COLLEGE            129291
# EDUCATION          128062
# ENVIRONMENT         78968
# MONEY               52470
# CULTURE & ARTS      51778
# Name: count, dtype: int64

# %% [markdown]
# ## Try to repair it

# %%
categories_list = [
    "POLITICS", "ENTERTAINMENT", "HEALTHY LIVING", "QUEER VOICES",
    "WELLNESS", "COMEDY", "WORLD NEWS", "SPORTS", "BLACK VOICES",
    "BUSINESS", "TRAVEL", "THE WORLDPOST", "PARENTS", "WOMEN", "CRIME",
    "MEDIA", "WEIRD NEWS", "PARENTING", "STYLE & BEAUTY", "IMPACT",
    "GREEN", "RELIGION", "FOOD & DRINK", "STYLE", "U.S. NEWS", "TASTE",
    "WORLDPOST", "TECH", "ARTS & CULTURE", "SCIENCE", "HOME & LIVING",
    "GOOD NEWS", "LATINO VOICES", "ARTS", "FIFTY", "WEDDINGS", "DIVORCE",
    "COLLEGE", "EDUCATION", "ENVIRONMENT", "MONEY", "CULTURE & ARTS"
]
categories_set = set(categories_list)

# %%
def detect_category_at_start(line, categories):
    
    line_stripped = line.strip()
    
    for cat in categories:
        if line_stripped.upper().startswith(cat.upper()):
            cat_len = len(cat)
            leftover = line_stripped[cat_len:]
            leftover = leftover.lstrip(' ,.:!?-—"\'')
            
            return cat.upper(), leftover
    return None, line

# %%
def parse_file_by_start_category(file_in, file_out):
    
    with open(file_in, "r", encoding="utf-8") as fin, \
         open(file_out, "w", encoding="utf-8") as fout:
        
        fout.write("category,content\n")
        
        current_category = None
        content_lines = []
        
        for line in fin:
            line_stripped = line.rstrip("\r\n")
            
            cat_found, leftover = detect_category_at_start(line_stripped, categories_list)
            
            if cat_found is not None:
                if current_category is not None:
                    content_text = " ".join(content_lines)
                    content_text = content_text.replace('"','""')
                    fout.write(f'"{current_category}","{content_text}"\n')
                
                current_category = cat_found
                content_lines = []
                
                if leftover.strip():
                    content_lines.append(leftover.strip())
            
            else:
                if line_stripped.strip():
                    content_lines.append(line_stripped.strip())
        
        if current_category is not None:
            content_text = " ".join(content_lines)
            content_text = content_text.replace('"','""')
            fout.write(f'"{current_category}","{content_text}"\n')

# %%
files_with_ext = glob.glob("../../datasets/Article_category/*.csv")

files = [os.path.splitext(os.path.basename(f))[0] for f in files_with_ext]

for file in files:
    file_in = os.path.join("../../datasets/Article_category", file + ".csv")
    file_out = os.path.join("../../datasets/Article_category", file + "_fixed.csv")
    parse_file_by_start_category(file_in, file_out)
    print(f"Processed: {file_in} -> {file_out}")
# Out:
# Processed: ../../datasets/Article_category/news_articles_content_part_23.csv -> ../../datasets/Article_category/news_articles_content_part_23_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_63.csv -> ../../datasets/Article_category/news_articles_content_part_63_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_113.csv -> ../../datasets/Article_category/news_articles_content_part_113_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_88.csv -> ../../datasets/Article_category/news_articles_content_part_88_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_58.csv -> ../../datasets/Article_category/news_articles_content_part_58_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_80.csv -> ../../datasets/Article_category/news_articles_content_part_80_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_76.csv -> ../../datasets/Article_category/news_articles_content_part_76_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_100.csv -> ../../datasets/Article_category/news_articles_content_part_100_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_36.csv -> ../../datasets/Article_category/news_articles_content_part_36_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_42.csv -> ../../datasets/Article_category/news_articles_content_part_42_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_38.csv -> ../../datasets/Article_category/news_articles_content_part_38_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_139.csv -> ../../datasets/Article_category/news_articles_content_part_139_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_148.csv -> ../../datasets/Article_category/news_articles_content_part_148_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_98.csv -> ../../datasets/Article_category/news_articles_content_part_98_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_158.csv -> ../../datasets/Article_category/news_articles_content_part_158_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_159.csv -> ../../datasets/Article_category/news_articles_content_part_159_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_201.csv -> ../../datasets/Article_category/news_articles_content_part_201_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_208.csv -> ../../datasets/Article_category/news_articles_content_part_208_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_197.csv -> ../../datasets/Article_category/news_articles_content_part_197_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_180.csv -> ../../datasets/Article_category/news_articles_content_part_180_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_32.csv -> ../../datasets/Article_category/news_articles_content_part_32_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_210.csv -> ../../datasets/Article_category/news_articles_content_part_210_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_179.csv -> ../../datasets/Article_category/news_articles_content_part_179_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_130.csv -> ../../datasets/Article_category/news_articles_content_part_130_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_44.csv -> ../../datasets/Article_category/news_articles_content_part_44_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_49.csv -> ../../datasets/Article_category/news_articles_content_part_49_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_120.csv -> ../../datasets/Article_category/news_articles_content_part_120_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_170.csv -> ../../datasets/Article_category/news_articles_content_part_170_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_195.csv -> ../../datasets/Article_category/news_articles_content_part_195_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_45.csv -> ../../datasets/Article_category/news_articles_content_part_45_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_54.csv -> ../../datasets/Article_category/news_articles_content_part_54_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_20.csv -> ../../datasets/Article_category/news_articles_content_part_20_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_67.csv -> ../../datasets/Article_category/news_articles_content_part_67_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_112.csv -> ../../datasets/Article_category/news_articles_content_part_112_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_185.csv -> ../../datasets/Article_category/news_articles_content_part_185_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_134.csv -> ../../datasets/Article_category/news_articles_content_part_134_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_24.csv -> ../../datasets/Article_category/news_articles_content_part_24_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_21.csv -> ../../datasets/Article_category/news_articles_content_part_21_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_51.csv -> ../../datasets/Article_category/news_articles_content_part_51_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_12.csv -> ../../datasets/Article_category/news_articles_content_part_12_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_29.csv -> ../../datasets/Article_category/news_articles_content_part_29_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_53.csv -> ../../datasets/Article_category/news_articles_content_part_53_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_4.csv -> ../../datasets/Article_category/news_articles_content_part_4_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_191.csv -> ../../datasets/Article_category/news_articles_content_part_191_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_61.csv -> ../../datasets/Article_category/news_articles_content_part_61_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_147.csv -> ../../datasets/Article_category/news_articles_content_part_147_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_116.csv -> ../../datasets/Article_category/news_articles_content_part_116_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_121.csv -> ../../datasets/Article_category/news_articles_content_part_121_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_168.csv -> ../../datasets/Article_category/news_articles_content_part_168_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_47.csv -> ../../datasets/Article_category/news_articles_content_part_47_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_151.csv -> ../../datasets/Article_category/news_articles_content_part_151_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_60.csv -> ../../datasets/Article_category/news_articles_content_part_60_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_77.csv -> ../../datasets/Article_category/news_articles_content_part_77_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_189.csv -> ../../datasets/Article_category/news_articles_content_part_189_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_105.csv -> ../../datasets/Article_category/news_articles_content_part_105_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_199.csv -> ../../datasets/Article_category/news_articles_content_part_199_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_169.csv -> ../../datasets/Article_category/news_articles_content_part_169_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_92.csv -> ../../datasets/Article_category/news_articles_content_part_92_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_84.csv -> ../../datasets/Article_category/news_articles_content_part_84_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_95.csv -> ../../datasets/Article_category/news_articles_content_part_95_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_15.csv -> ../../datasets/Article_category/news_articles_content_part_15_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_27.csv -> ../../datasets/Article_category/news_articles_content_part_27_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_122.csv -> ../../datasets/Article_category/news_articles_content_part_122_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_198.csv -> ../../datasets/Article_category/news_articles_content_part_198_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_127.csv -> ../../datasets/Article_category/news_articles_content_part_127_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_6.csv -> ../../datasets/Article_category/news_articles_content_part_6_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_175.csv -> ../../datasets/Article_category/news_articles_content_part_175_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_152.csv -> ../../datasets/Article_category/news_articles_content_part_152_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_181.csv -> ../../datasets/Article_category/news_articles_content_part_181_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_103.csv -> ../../datasets/Article_category/news_articles_content_part_103_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_119.csv -> ../../datasets/Article_category/news_articles_content_part_119_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_141.csv -> ../../datasets/Article_category/news_articles_content_part_141_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_108.csv -> ../../datasets/Article_category/news_articles_content_part_108_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_128.csv -> ../../datasets/Article_category/news_articles_content_part_128_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_143.csv -> ../../datasets/Article_category/news_articles_content_part_143_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_188.csv -> ../../datasets/Article_category/news_articles_content_part_188_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_160.csv -> ../../datasets/Article_category/news_articles_content_part_160_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_2.csv -> ../../datasets/Article_category/news_articles_content_part_2_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_136.csv -> ../../datasets/Article_category/news_articles_content_part_136_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_142.csv -> ../../datasets/Article_category/news_articles_content_part_142_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_72.csv -> ../../datasets/Article_category/news_articles_content_part_72_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_8.csv -> ../../datasets/Article_category/news_articles_content_part_8_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_123.csv -> ../../datasets/Article_category/news_articles_content_part_123_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_150.csv -> ../../datasets/Article_category/news_articles_content_part_150_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_163.csv -> ../../datasets/Article_category/news_articles_content_part_163_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_31.csv -> ../../datasets/Article_category/news_articles_content_part_31_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_177.csv -> ../../datasets/Article_category/news_articles_content_part_177_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_204.csv -> ../../datasets/Article_category/news_articles_content_part_204_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_94.csv -> ../../datasets/Article_category/news_articles_content_part_94_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_93.csv -> ../../datasets/Article_category/news_articles_content_part_93_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_39.csv -> ../../datasets/Article_category/news_articles_content_part_39_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_62.csv -> ../../datasets/Article_category/news_articles_content_part_62_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_46.csv -> ../../datasets/Article_category/news_articles_content_part_46_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_132.csv -> ../../datasets/Article_category/news_articles_content_part_132_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_206.csv -> ../../datasets/Article_category/news_articles_content_part_206_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_156.csv -> ../../datasets/Article_category/news_articles_content_part_156_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_166.csv -> ../../datasets/Article_category/news_articles_content_part_166_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_125.csv -> ../../datasets/Article_category/news_articles_content_part_125_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_109.csv -> ../../datasets/Article_category/news_articles_content_part_109_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_30.csv -> ../../datasets/Article_category/news_articles_content_part_30_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_43.csv -> ../../datasets/Article_category/news_articles_content_part_43_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_82.csv -> ../../datasets/Article_category/news_articles_content_part_82_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_18.csv -> ../../datasets/Article_category/news_articles_content_part_18_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_68.csv -> ../../datasets/Article_category/news_articles_content_part_68_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_55.csv -> ../../datasets/Article_category/news_articles_content_part_55_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_162.csv -> ../../datasets/Article_category/news_articles_content_part_162_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_81.csv -> ../../datasets/Article_category/news_articles_content_part_81_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_5.csv -> ../../datasets/Article_category/news_articles_content_part_5_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_173.csv -> ../../datasets/Article_category/news_articles_content_part_173_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_133.csv -> ../../datasets/Article_category/news_articles_content_part_133_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_164.csv -> ../../datasets/Article_category/news_articles_content_part_164_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_28.csv -> ../../datasets/Article_category/news_articles_content_part_28_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_91.csv -> ../../datasets/Article_category/news_articles_content_part_91_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_196.csv -> ../../datasets/Article_category/news_articles_content_part_196_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_178.csv -> ../../datasets/Article_category/news_articles_content_part_178_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_106.csv -> ../../datasets/Article_category/news_articles_content_part_106_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_89.csv -> ../../datasets/Article_category/news_articles_content_part_89_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_118.csv -> ../../datasets/Article_category/news_articles_content_part_118_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_33.csv -> ../../datasets/Article_category/news_articles_content_part_33_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_104.csv -> ../../datasets/Article_category/news_articles_content_part_104_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_209.csv -> ../../datasets/Article_category/news_articles_content_part_209_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_13.csv -> ../../datasets/Article_category/news_articles_content_part_13_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_190.csv -> ../../datasets/Article_category/news_articles_content_part_190_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_48.csv -> ../../datasets/Article_category/news_articles_content_part_48_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_192.csv -> ../../datasets/Article_category/news_articles_content_part_192_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_85.csv -> ../../datasets/Article_category/news_articles_content_part_85_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_57.csv -> ../../datasets/Article_category/news_articles_content_part_57_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_17.csv -> ../../datasets/Article_category/news_articles_content_part_17_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_176.csv -> ../../datasets/Article_category/news_articles_content_part_176_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_186.csv -> ../../datasets/Article_category/news_articles_content_part_186_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_149.csv -> ../../datasets/Article_category/news_articles_content_part_149_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_3.csv -> ../../datasets/Article_category/news_articles_content_part_3_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_165.csv -> ../../datasets/Article_category/news_articles_content_part_165_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_126.csv -> ../../datasets/Article_category/news_articles_content_part_126_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_52.csv -> ../../datasets/Article_category/news_articles_content_part_52_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_146.csv -> ../../datasets/Article_category/news_articles_content_part_146_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_138.csv -> ../../datasets/Article_category/news_articles_content_part_138_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_25.csv -> ../../datasets/Article_category/news_articles_content_part_25_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_157.csv -> ../../datasets/Article_category/news_articles_content_part_157_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_115.csv -> ../../datasets/Article_category/news_articles_content_part_115_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_172.csv -> ../../datasets/Article_category/news_articles_content_part_172_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_96.csv -> ../../datasets/Article_category/news_articles_content_part_96_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_78.csv -> ../../datasets/Article_category/news_articles_content_part_78_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_19.csv -> ../../datasets/Article_category/news_articles_content_part_19_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_131.csv -> ../../datasets/Article_category/news_articles_content_part_131_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_111.csv -> ../../datasets/Article_category/news_articles_content_part_111_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_87.csv -> ../../datasets/Article_category/news_articles_content_part_87_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_37.csv -> ../../datasets/Article_category/news_articles_content_part_37_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_97.csv -> ../../datasets/Article_category/news_articles_content_part_97_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_71.csv -> ../../datasets/Article_category/news_articles_content_part_71_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_110.csv -> ../../datasets/Article_category/news_articles_content_part_110_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_101.csv -> ../../datasets/Article_category/news_articles_content_part_101_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_137.csv -> ../../datasets/Article_category/news_articles_content_part_137_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_203.csv -> ../../datasets/Article_category/news_articles_content_part_203_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_50.csv -> ../../datasets/Article_category/news_articles_content_part_50_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_153.csv -> ../../datasets/Article_category/news_articles_content_part_153_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_22.csv -> ../../datasets/Article_category/news_articles_content_part_22_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_99.csv -> ../../datasets/Article_category/news_articles_content_part_99_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_102.csv -> ../../datasets/Article_category/news_articles_content_part_102_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_184.csv -> ../../datasets/Article_category/news_articles_content_part_184_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_200.csv -> ../../datasets/Article_category/news_articles_content_part_200_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_65.csv -> ../../datasets/Article_category/news_articles_content_part_65_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_86.csv -> ../../datasets/Article_category/news_articles_content_part_86_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_129.csv -> ../../datasets/Article_category/news_articles_content_part_129_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_74.csv -> ../../datasets/Article_category/news_articles_content_part_74_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_14.csv -> ../../datasets/Article_category/news_articles_content_part_14_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_59.csv -> ../../datasets/Article_category/news_articles_content_part_59_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_140.csv -> ../../datasets/Article_category/news_articles_content_part_140_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_70.csv -> ../../datasets/Article_category/news_articles_content_part_70_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_9.csv -> ../../datasets/Article_category/news_articles_content_part_9_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_145.csv -> ../../datasets/Article_category/news_articles_content_part_145_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_10.csv -> ../../datasets/Article_category/news_articles_content_part_10_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_35.csv -> ../../datasets/Article_category/news_articles_content_part_35_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_187.csv -> ../../datasets/Article_category/news_articles_content_part_187_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_1.csv -> ../../datasets/Article_category/news_articles_content_part_1_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_79.csv -> ../../datasets/Article_category/news_articles_content_part_79_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_124.csv -> ../../datasets/Article_category/news_articles_content_part_124_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_69.csv -> ../../datasets/Article_category/news_articles_content_part_69_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_205.csv -> ../../datasets/Article_category/news_articles_content_part_205_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_90.csv -> ../../datasets/Article_category/news_articles_content_part_90_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_182.csv -> ../../datasets/Article_category/news_articles_content_part_182_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_73.csv -> ../../datasets/Article_category/news_articles_content_part_73_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_155.csv -> ../../datasets/Article_category/news_articles_content_part_155_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_40.csv -> ../../datasets/Article_category/news_articles_content_part_40_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_167.csv -> ../../datasets/Article_category/news_articles_content_part_167_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_154.csv -> ../../datasets/Article_category/news_articles_content_part_154_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_114.csv -> ../../datasets/Article_category/news_articles_content_part_114_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_11.csv -> ../../datasets/Article_category/news_articles_content_part_11_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_64.csv -> ../../datasets/Article_category/news_articles_content_part_64_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_183.csv -> ../../datasets/Article_category/news_articles_content_part_183_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_75.csv -> ../../datasets/Article_category/news_articles_content_part_75_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_107.csv -> ../../datasets/Article_category/news_articles_content_part_107_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_56.csv -> ../../datasets/Article_category/news_articles_content_part_56_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_202.csv -> ../../datasets/Article_category/news_articles_content_part_202_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_193.csv -> ../../datasets/Article_category/news_articles_content_part_193_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_161.csv -> ../../datasets/Article_category/news_articles_content_part_161_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_171.csv -> ../../datasets/Article_category/news_articles_content_part_171_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_66.csv -> ../../datasets/Article_category/news_articles_content_part_66_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_16.csv -> ../../datasets/Article_category/news_articles_content_part_16_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_117.csv -> ../../datasets/Article_category/news_articles_content_part_117_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_41.csv -> ../../datasets/Article_category/news_articles_content_part_41_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_174.csv -> ../../datasets/Article_category/news_articles_content_part_174_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_83.csv -> ../../datasets/Article_category/news_articles_content_part_83_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_26.csv -> ../../datasets/Article_category/news_articles_content_part_26_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_135.csv -> ../../datasets/Article_category/news_articles_content_part_135_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_194.csv -> ../../datasets/Article_category/news_articles_content_part_194_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_7.csv -> ../../datasets/Article_category/news_articles_content_part_7_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_34.csv -> ../../datasets/Article_category/news_articles_content_part_34_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_207.csv -> ../../datasets/Article_category/news_articles_content_part_207_fixed.csv
# Processed: ../../datasets/Article_category/news_articles_content_part_144.csv -> ../../datasets/Article_category/news_articles_content_part_144_fixed.csv

# %%
df = pd.read_csv(file_out)

# %%
df.value_counts("category")
# Out:
# category
# POLITICS          273
# ENTERTAINMENT     185
# U.S. NEWS         174
# WORLD NEWS        138
# SPORTS             36
# CRIME              26
# ENVIRONMENT        25
# CULTURE & ARTS     23
# WELLNESS           16
# PARENTING          15
# FOOD & DRINK       14
# WEIRD NEWS         14
# COMEDY             11
# STYLE & BEAUTY      9
# BUSINESS            9
# TECH                9
# GREEN               8
# SCIENCE             6
# WOMEN               5
# MEDIA               4
# EDUCATION           3
# PARENTS             3
# HOME & LIVING       3
# BLACK VOICES        3
# STYLE               2
# QUEER VOICES        2
# TRAVEL              2
# FIFTY               1
# COLLEGE             1
# Name: count, dtype: int64

# %%
input_dir = "../../datasets/Article_category"  

csv_files = glob.glob(os.path.join(input_dir, "*fixed.csv"))
print(f"Număr fișiere CSV găsite: {len(csv_files)}")

df_list = []
for file in csv_files:
    try:
        df = pd.read_csv(file, on_bad_lines='skip', engine='python')
        df_list.append(df)
    except Exception as e:
        print(f"Eroare la citirea fișierului {file}: {e}")

df_all = pd.concat(df_list, ignore_index=True)
print(f"Număr total de articole combinate: {len(df_all)}")
# Out:
# Număr fișiere CSV găsite: 210
# Număr total de articole combinate: 22288851

# %%
print("Numarul de valori lipsa in df_all:", df_all.isnull().sum())
# Out:
# Numarul de valori lipsa in df_all: category           0
# content     17512558
# dtype: int64

# %%
from collections import Counter

df = pd.read_csv("news_dataset.csv")  

line_counter = Counter()

for content in df["content"].dropna():
    lines = content.splitlines()
    line_counter.update(lines)

most_common_lines = line_counter.most_common(50)
for line, freq in most_common_lines:
    print(f"[{freq} apariții] {repr(line)}")
