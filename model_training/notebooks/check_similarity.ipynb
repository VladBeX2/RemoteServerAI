# %%
from datasketch import MinHash, MinHashLSH
import pandas as pd

def get_minhash(text, num_perm=128):
    """
    Creează obiectul MinHash pentru un text dat.
    num_perm este numărul de permutări folosite pentru MinHash.
    """
    m = MinHash(num_perm=num_perm)
    # Împarte textul în cuvinte (folosim set() pentru a evita duplicările)
    for word in set(text.split()):
        m.update(word.encode('utf8'))
    return m

def find_near_duplicates_lsh(texts, threshold=0.7, num_perm=128):
    """
    Caută near-duplicates într-o listă de texte folosind LSH pe baza semnăturilor MinHash.
    - threshold: pragul de similaritate Jaccard pentru a considera două texte near duplicates.
    - num_perm: numărul de permutări pentru MinHash.
    
    Returnează o listă de tuple (i, j, score) unde textul i este near duplicate cu textul j,
    iar score este similaritatea Jaccard calculată.
    """
    # Inițializăm un index LSH cu pragul de similaritate dat
    lsh = MinHashLSH(threshold=threshold, num_perm=num_perm)
    
    # Creăm și inserăm semnăturile MinHash pentru fiecare text
    minhashes = []
    for i, text in enumerate(texts):
        mh = get_minhash(text, num_perm)
        lsh.insert(i, mh)
        minhashes.append((i, mh))
    
    near_dups = []
    # Pentru fiecare semnătură, interogăm LSH pentru a găsi candidate near-duplicate
    for i, mh in minhashes:
        results = lsh.query(mh)
        for r in results:
            if r != i and r > i:  # evităm duplicatele și perechile inverse
                # Calculăm similaritatea Jaccard între semnătura curentă și cea a textului din candidate
                score = mh.jaccard(minhashes[r][1])
                # Dacă scorul este peste pragul definit, adăugăm perechea și scorul
                if score >= threshold:
                    near_dups.append((i, r, score))
    return near_dups

# %%
path = "../datasets/CC_MC_WELF_merged.csv"
df = pd.read_csv(path)
texts = df["text"].tolist()
df = df.dropna(subset=['text'])
# Păstrează doar rândurile unde "text" este string
df = df[df['text'].apply(lambda x: isinstance(x, str))]

texts = df['text'].tolist()


# Caută near duplicates cu pragul de similaritate Jaccard setat la 0.7
near_dup_all = find_near_duplicates_lsh(texts, threshold=0.9, num_perm=128)

print("Numărul de near-duplicates găsite:", len(near_dup_all))
for i, j, sim in near_dup_all[:20]:  # afișăm doar primele 20 de exemple
    print(f"Textul cu index {i} este near-duplicate cu textul cu index {j} (similaritate: {sim:.2f})")
# Out:
# Numărul de near-duplicates găsite: 321
# Textul cu index 10883 este near-duplicate cu textul cu index 173064 (similaritate: 0.96)
# Textul cu index 19393 este near-duplicate cu textul cu index 150768 (similaritate: 0.96)
# Textul cu index 19578 este near-duplicate cu textul cu index 164366 (similaritate: 0.94)
# Textul cu index 19730 este near-duplicate cu textul cu index 156020 (similaritate: 0.98)
# Textul cu index 19796 este near-duplicate cu textul cu index 128947 (similaritate: 0.97)
# Textul cu index 21040 este near-duplicate cu textul cu index 164315 (similaritate: 0.92)
# Textul cu index 23280 este near-duplicate cu textul cu index 153830 (similaritate: 0.93)
# Textul cu index 23363 este near-duplicate cu textul cu index 135092 (similaritate: 0.93)
# Textul cu index 23380 este near-duplicate cu textul cu index 143442 (similaritate: 0.92)
# Textul cu index 23397 este near-duplicate cu textul cu index 150794 (similaritate: 0.92)
# Textul cu index 23520 este near-duplicate cu textul cu index 161084 (similaritate: 0.92)
# Textul cu index 23567 este near-duplicate cu textul cu index 130607 (similaritate: 0.96)
# Textul cu index 23580 este near-duplicate cu textul cu index 141123 (similaritate: 0.95)
# Textul cu index 23597 este near-duplicate cu textul cu index 115257 (similaritate: 0.92)
# Textul cu index 23725 este near-duplicate cu textul cu index 139953 (similaritate: 0.97)
# Textul cu index 23792 este near-duplicate cu textul cu index 153008 (similaritate: 0.96)
# Textul cu index 23802 este near-duplicate cu textul cu index 124622 (similaritate: 1.00)
# Textul cu index 23865 este near-duplicate cu textul cu index 172073 (similaritate: 0.95)
# Textul cu index 24171 este near-duplicate cu textul cu index 157574 (similaritate: 0.97)
# Textul cu index 24212 este near-duplicate cu textul cu index 139766 (similaritate: 0.92)

# %%
import csv

# Salvează lista near_dup_all într-un fișier CSV
output_file = "near_duplicates_CC_MC_WF_merged.csv"
with open(output_file, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    # Scrie antetul
    writer.writerow(["index1", "index2", "similarity"])
    # Scrie fiecare tuplu (index1, index2, score)
    for i, j, sim in near_dup_all:
        writer.writerow([i, j, sim])

print(f"Rezultatele au fost salvate în fișierul '{output_file}'.")
# Out:
# Rezultatele au fost salvate în fișierul 'near_duplicates_merged.csv'.

# %%
import csv

# Salvează lista near_dup_all într-un fișier CSV, inclusiv coloana "source" pentru fiecare articol
output_file = "near_duplicates_CC_MC_WF_merged.csv"
with open(output_file, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    # Scrie antetul: includem indexele, similaritatea și sursele pentru fiecare articol duplicat
    writer.writerow(["index1", "index2", "similarity", "source1", "source2"])
    # Pentru fiecare tuplu (i, j, sim), extragem sursa din DataFrame
    for i, j, sim in near_dup_all:
        source_i = df.iloc[i]["source"]
        source_j = df.iloc[j]["source"]
        writer.writerow([i, j, sim, source_i, source_j])

print(f"Rezultatele au fost salvate în fișierul '{output_file}'.")
# Out:
# Rezultatele au fost salvate în fișierul 'near_duplicates_CC_MC_WF_merged.csv'.

# %%
df[df['label'] == 1].shape[0]
# Out:
# 4393

# %%
import textwrap
index = 117768                  
  # poți schimba cu orice alt rând vrei să vezi
text = df["text"].iloc[index]
label = df["label"].iloc[index]
category = df["category"].iloc[index]
language = df["language"].iloc[index]
wrapped = textwrap.fill(text, width=100)
word_count  = len(text.split())
print(f"Numărul de cuvinte: {word_count}")
print(wrapped)
print(f"Textul cu index {index} (eticheta: {label}):")
print(f"Category: {category}")
print(f"language: {language}")
print("-------------------------------------------------")
index2 = 112520  
label2 = df["label"].iloc[index2]
category2 = df["category"].iloc[index2]
language2 = df["language"].iloc[index2]
print(f"language: {language2}")
print(f"Category: {category2}")
print(f"Textul cu index {index2} (eticheta: {label2}):")
text2 = df["text"].iloc[index2]

wrapped2 = textwrap.fill(text2, width=100)
print(wrapped2)
# Out:
# Numărul de cuvinte: 1564
# An Islamic State disciple kills 39 New Year’s revelers at an Istanbul nightclub. A gunman with a
# police badge assassinates Russia’s ambassador at an Ankara reception. Kurdish separatist bombers
# obvious, very serious and problematic disrespect against Turkeyâ€™s right to defend itself against
# terror,â€ said Mustafa Yeneroglu, a member of Parliament with Mr. Erdoganâ€™s Islamist Justice and
# Development Party. Mr. Yeneroglu, the head of Parliamentâ€™s human rights committee, said Turkey
# faced the same conundrum any country faces when traumatized by terrorist acts. â€œIf there is no
# security, there would be no room to enjoy the liberties,â€ he said. â€œThis situation leads to
# prioritizing security while answering questions, â€˜security or liberty?â€™ This is not only valid
# for Turkey but for all other liberal democracies. â€ Turkish liberals say they understand the need
# for extraordinary measures, but they make two counter arguments. One is that Turkeyâ€™s broad
# crackdown  â€”   in putting so many journalists and intellectuals in jail  â€”   has gone too far,
# and is seemingly unrelated to fighting terrorism. Another is that, even with emergency rule, the
# country has become less safe. â€œOn the contrary, we have faced more attacks, more terror,â€ said
# Yaman Akdeniz, a lawyer and professor at Bilgi University in Istanbul who represents many jailed
# journalists. He continued, â€œthere is emergency rule in France, but there is no other country
# limiting fundamental rights and freedoms on this scale. â€ Orhan Kemal Cengiz, a prominent human
# rights lawyer who was briefly detained after the attempted coup, put it this way: â€œYes, ISIS is
# attacking. The P. K. K. is attacking. There was this coup dâ€™Ã©tat attempt. But what is this to do
# with all these journalists? There are over 150 journalists in jail. And with every passing day, they
# arrest more and more people. â€ Marc Pierini, a visiting scholar at Carnegie Europe in Brussels who
# was a former European Union ambassador to Turkey, said the   purges in the military, the courts and
# the police have, paradoxically, compromised the countryâ€™s ability to protect the public. Mr.
# Pierini also took issue with the governmentâ€™s contention that its response to threats has been
# appropriate. â€œAs weâ€™ve seen after the coup, the reaction is way outside of the formal rule of
# law. You started arresting police and gendarmes, now writers, actors, journalists  â€”   so there is
# no limit,â€ he said. â€œWhen you start pulling the thread on the rule of law, the whole sweater can
# come off. And thatâ€™s where we stand. â€

# %%
# lets see if in near_dup_all are texts with different labels
# let's check if in near_dup_all are texts with different labels
different_labels = []
for i, j, sim in near_dup_all:
    if df.iloc[i]["label"] != df.iloc[j]["label"]:
        different_labels.append((i, j, sim))
print(f"Numărul de perechi cu etichete diferite: {len(different_labels)}")
for i, j, sim in different_labels[:20]:  # afișăm doar primele 20 de exemple
    print(f"Textul cu index {i} (eticheta: {df.iloc[i]['label']}) este near-duplicate cu textul cu index {j} (eticheta: {df.iloc[j]['label']}) (similaritate: {sim:.2f})")
# Out:
# Numărul de perechi cu etichete diferite: 0

# %%
df.sample(5)
# Out:
#                   news_id                                              title  \
# 20691   RealHealth-212946  Judges Are Forcing People to Get Mental Health...
# 24402  SyriaHealth-130597  Star soccer player turned rebel icon dies in S...
# 15015    RealCovid_000115  Coronavirus a global health emergency? WHO chi...
# 4768     gossipcop-919177  why hoda kotb isn’t making matt lauer’s salary...
# 20713   RealHealth-220945  How Mainstream Emo Made Us Talk About Mental H...
#
#                                                      url         publish_date  \
# 20691  https://www.vice.com/en_us/article/kzv8ba/assi...  2018-11-12 23:24:00
# 24402  https://www.reuters.com/article/us-syria-secur...  2019-06-08 00:00:00
# 15015                                                NaN                  NaN
# 4768   https://variety.com/2018/tv/news/hoda-kotb-sal...         1515009580.0
# 20713  https://www.vice.com/en_us/article/rgp7wb/how-...  2016-05-18 10:38:00
#
#                     source                                               text  \
# 20691                  NaN  When mental illness hijacks Margaret Rodgers’ ...
# 24402                  NaN  AZAZ, Syria (Reuters) - A Syrian star soccer p...
# 15015                  NaN  The head of the World Health Organization on W...
# 4768   https://variety.com  In the world of TV news, there’s an inordinate...
# 20713                  NaN  This feature is part of 'The Noisey Guide to M...
#
#        label  n_tweets  n_retweets  n_replies  n_users  \
# 20691      0         5           0          0        5
# 24402      0        42           4          0       46
# 15015      0         6           0          0        5
# 4768       0        14           0          0       11
# 20713      0       167         165         16      330
#
#                                                tweet_ids  \
# 20691  1062135248065044480,1062139894993223680,106215...
# 24402  1137375165728284674,1137375500635009025,113737...
# 15015  1222576978160758785,1222581586522230784,122258...
# 4768   948645557601480705,948646467992014848,94864695...
# 20713  732909833771421696,732915363109801984,73294194...
#
#                                              retweet_ids  \
# 20691                                                NaN
# 24402  1137388906356334600,1137411243596165120,113755...
# 15015                                                NaN
# 4768                                                 NaN
# 20713  732910832191967232,732911432451411970,73291385...
#
#                                                reply_ids  \
# 20691                                                NaN
# 24402                                                NaN
# 15015                                                NaN
# 4768                                                 NaN
# 20713  733046296248995840,733094873490960384,73309487...
#
#                                                 user_ids  \
# 20691    58851397,43241420,165462640,424033719,288586365
# 24402  749646098273144832,728200388890001408,76427902...
# 15015  1196340921303891968,1216824204013654016,122203...
# 4768   748194188060139520,754545110818426881,71859482...
# 20713  1229168245921456128,751308498047111169,9765635...
#
#                                        retweet_relations  \
# 20691                                                NaN
# 24402  1137388906356334600-1137388053415235586-271734...
# 15015                                                NaN
# 4768                                                 NaN
# 20713  732910832191967232-732909833771421696-15995155...
#
#                                          reply_relations   data_name language  \
# 20691                                                NaN  RealHealth       en
# 24402                                                NaN   RealSyria       en
# 15015                                                NaN   RealCovid       en
# 4768                                                 NaN   gossipcop       en
# 20713  733046296248995840-733044528999866369-28868871...  RealHealth       en
#
#                 category
# 20691  WELLNESS & HEALTH
# 24402          WORLDPOST
# 15015         WORLD NEWS
# 4768               MEDIA
# 20713  WELLNESS & HEALTH

# %%
df.shape
# Out:
# (28133, 20)

# %%
def remove_near_duplicates(df, near_dup_all, label_col="label"):
    """
    Elimină near-duplicatele dintr-un DataFrame conform regulilor:
      - Dacă (i, j) au același label => eliminăm doar j.
      - Dacă (i, j) au label diferit => eliminăm ambele.
    
    Args:
      df (pd.DataFrame): DataFrame cu index 0..n-1 sincronizat cu near_dup_all.
      near_dup_all (list of tuples): listă de (i, j, sim).
      label_col (str): numele coloanei de label.
    
    Returnează:
      df_curatat (pd.DataFrame): DataFrame după eliminare
      conflict_count (int): număr de perechi care au label diferit
      removed_count (int): număr total de articole eliminate
    """
    
    to_remove = set()       # set de indexi care vor fi eliminați
    conflict_count = 0      # câte perechi au label diferit
    
    for (i, j, sim) in near_dup_all:
        # Dacă deja i sau j a fost marcat pentru ștergere, sărim peste
        if i in to_remove or j in to_remove:
            continue
        
        label_i = df.iloc[i][label_col]
        label_j = df.iloc[j][label_col]
        
        if label_i != label_j:
            # Avem conflict, eliminăm ambele
            conflict_count += 1
            to_remove.add(i)
            to_remove.add(j)
        else:
            # Au același label => eliminăm j
            to_remove.add(j)
    
    # Construim noul DataFrame fără articolele eliminate
    initial_count = len(df)
    df_curatat = df.drop(labels=to_remove, axis=0)
    df_curatat.reset_index(drop=True, inplace=True)  # Reindexăm dacă e nevoie
    
    removed_count = len(to_remove)
    
    return df_curatat, conflict_count, removed_count

# %%
df_clean, conflict_count, removed_count = remove_near_duplicates(df, near_dup_all, label_col="label")

    # 4) Afișăm statistici
print(f"Număr de perechi cu label diferit (conflicte): {conflict_count}")
print(f"Număr total de articole eliminate: {removed_count}")
print(f"Dimensiunea inițială a datasetului: {len(df)}")
print(f"Dimensiunea finală a datasetului: {len(df_clean)}")
# Out:
# Număr de perechi cu label diferit (conflicte): 34
# Număr total de articole eliminate: 785
# Dimensiunea inițială a datasetului: 28133
# Dimensiunea finală a datasetului: 27348

# %%
df_clean[df_clean['label'] == 1].shape[0]
# Out:
# 4218

# %%
print(df.shape)
print(df_clean.shape)
# Out:
# (28133, 20)
# (27348, 20)

# %%
df_clean.sample(5)
# Out:
#                     news_id  \
# 2509   gossipcop-2628357669
# 18362      RealCovid_006148
# 21417     RealHealth-624240
# 3816   gossipcop-3885971599
# 22864     RealHealth-910087
#
#                                                    title  \
# 2509   angelina jolie & brad pitt kicked off valentin...
# 18362  Coronavirus could live in the body for 5 weeks...
# 21417  Tropical Depression Three forms over Bahamas, ...
# 3816   malibu crash involving bruce jenner leaves 1 d...
# 22864  Industry funded studies don't find sweet drink...
#
#                                                      url         publish_date  \
# 2509   perezhilton.com/2013-02-15-angelina-jolie-brad...         1360886400.0
# 18362                                                NaN                  NaN
# 21417  https://www.reuters.com/article/us-storm-tropi...  2019-07-22 00:00:00
# 3816   www.latimes.com/local/lanow/la-me-ln-bruce-jen...         1423238400.0
# 22864  http://www.reuters.com/article/us-health-resea...           2016-10-31
#
#                        source  \
# 2509   http://perezhilton.com
# 18362                     NaN
# 21417                     NaN
# 3816   http://www.latimes.com
# 22864                     NaN
#
#                                                     text  label  n_tweets  \
# 2509   Angelina Jolie & Brad Pitt Kicked Off Valentin...      1       100
# 18362  From coronavirus reports on new symptoms, self...      0        27
# 21417  (Reuters) - Tropical Depression Three has form...      0         8
# 3816   Former Olympian Bruce Jenner was a driver in a...      1       348
# 22864  By Andrew M. Seaman (Reuters Health) - Do suga...      0       348
#
#        n_retweets  n_replies  n_users  \
# 2509            0          0       98
# 18362          13          0       36
# 21417           0          0        7
# 3816          256         28      498
# 22864          41          4      358
#
#                                                tweet_ids  \
# 2509   302538297807339520,302538659960328192,30253951...
# 18362  1238541123800281088,1238545522400657410,123854...
# 21417  1153414031606239232,1153430798659440641,115345...
# 3816   564194031152795648,564194284513927169,56419509...
# 22864  793219861568630784,793219863892209664,79321987...
#
#                                              retweet_ids  \
# 2509                                                 NaN
# 18362  1238660065864945664,1238660767999803393,123866...
# 21417                                                NaN
# 3816   564194266218369025,564194663288950784,56419476...
# 22864  793229643742523393,793230363594067968,79323325...
#
#                                                reply_ids  \
# 2509                                                 NaN
# 18362                                                NaN
# 21417                                                NaN
# 3816   564202181826318336,564212153549611009,56421409...
# 22864  793240101123948544,793456228567572484,79348030...
#
#                                                 user_ids  \
# 2509   241058308,101366796,42277406,75464738,36522089...
# 18362  3053739264,843691263878729728,1090879834740256...
# 21417  1141007227395936256,855845233610768385,8020685...
# 3816   268899328,1148765700,15750149,380873739,275701...
# 22864  749978398886330368,890041994008961025,76010817...
#
#                                        retweet_relations  \
# 2509                                                 NaN
# 18362  1238660065864945664-1238655870659166209-109134...
# 21417                                                NaN
# 3816   564194266218369025-564194031152795648-58422278...
# 22864  793229643742523393-793226485226147840-91826981...
#
#                                          reply_relations   data_name language  \
# 2509                                                 NaN   gossipcop       en
# 18362                                                NaN   RealCovid       en
# 21417                                                NaN  RealHealth       en
# 3816   564202181826318336-564194031152795648-28899160...   gossipcop       en
# 22864  793240101123948544-793226485226147840-15389667...  RealHealth       en
#
#                 category
# 2509           PARENTING
# 18362  WELLNESS & HEALTH
# 21417        ENVIRONMENT
# 3816               CRIME
# 22864  WELLNESS & HEALTH

# %%
#drop everything except title, text, label, category, language
df_clean = df_clean[['title', 'text', 'label', 'category', 'language']]

# %%
df_clean.to_csv("../datasets/MC_Fake_cleaned.csv", index=False)

# %% [markdown]
# ## Combine CC and WELFake

# %%
import pandas as pd
df_ccwf = pd.read_csv("../datasets/CC_WELF_merged_cleaned.csv")
df_ccwf.sample(5)
# Out:
#                                                      text  label language  \
# 7663    Chris Wallace Refuses To Help Liberals Smear T...      0       en
# 25702   The second trailer for Beauty and the Beast ha...      1       en
# 132984  The White House Domestic Policy Council (DPC) ...      1       en
# 120052  President Barack Obama on Sunday campaigned in...      1       en
# 130926  Contact Us WikiLeaks: Hillary Admits Clinton F...      0       en
#
#              category                                              title
# 7663         POLITICS                                                NaN
# 25702   ENTERTAINMENT                                                NaN
# 132984       POLITICS  White House domestic advisers take lead on ref...
# 120052       POLITICS  Obama turns focus to U.S. Congress as he campa...
# 130926       POLITICS  WikiLeaks: Hillary Admits Clinton Foundation D...

# %%
df_mc = pd.read_csv("../datasets/MC_Fake_cleaned.csv")
df_mc.sample(5)
# Out:
#                                                    title  \
# 14616  British Airways suspends all flights to China ...
# 12617  ‘handmaid’s tale’ fans aren’t here for offred’...
# 19536  Sleep Deprivation Is a Surprisingly Effective ...
# 9699   'what really hurt': jay-z opens up about alleg...
# 9243   golden globes 2019: the complete list of nominees
#
#                                                     text  label  \
# 14616  British Airways has suspended all direct fligh...      0
# 12617  (Spoiler alert: Please do not read ahead if yo...      0
# 19536  Angelina is coming to life, precisely as my bo...      0
# 9699   Jay-Z said Kanye West's rant against him last ...      0
# 9243   The nominees are in for next month’s 76th annu...      0
#
#                 category language
# 14616             TRAVEL       en
# 12617      ENTERTAINMENT       en
# 19536  WELLNESS & HEALTH       en
# 9699       ENTERTAINMENT       en
# 9243       ENTERTAINMENT       en

# %%
# df_wf = df_wf.drop(columns=['Unnamed: 0'])
# df_wf.head(5)
# Out:
#                                                title  \
# 0  LAW ENFORCEMENT ON HIGH ALERT Following Threat...
# 1  UNBELIEVABLE! OBAMA’S ATTORNEY GENERAL SAYS MO...
# 2  Bobby Jindal, raised Hindu, uses story of Chri...
# 3  SATAN 2: Russia unvelis an image of its terrif...
# 4  About Time! Christian Group Sues Amazon and SP...
#
#                                                 text  label language  \
# 0  No comment is expected from Barack Obama Membe...      1       en
# 1   Now, most of the demonstrators gathered last ...      1       en
# 2  A dozen politically active pastors came here f...      0       en
# 3  The RS-28 Sarmat missile, dubbed Satan 2, will...      1       en
# 4  All we can say on this one is it s about time ...      1       en
#
#           category
# 0  MINORITY VOICES
# 1         POLITICS
# 2         RELIGION
# 3        WORLDPOST
# 4         RELIGION

# %%
# au LABEL-urile OPUSE => pastram labelurile CC pentru ca sunt mai multe
df_mc[df_mc['label'] == 1].shape[0]
# df_mc['label'] = 1 - df_mc['label']
# df_mc.head(5)
# Out:
# 23130

# %%
df_mc['text'] = [x.encode('ascii', 'ignore').decode('ascii') for x in df_mc['text']]

# %%
df_merged = pd.concat([df_ccwf, df_mc], ignore_index=True, sort=False)
df_merged.sample(5)
# Out:
#                                                      text  label language  \
# 96792   Officers with U. S. Customs and Border Protect...      1       en
# 32993   Bats rely on the position of the sun at sunset...      1       en
# 21050   All the Creepy Ways Big Brother Is Watching Yo...      0       en
# 22286   Sheku Kanneh-Mason, 17, is a cellist who in Ma...      1       en
# 113268  (Want to get this briefing by email? Heres the...      1       en
#
#              category                                              title
# 96792           CRIME  Feds Seize $7.2 Million in Drugs at Border in Day
# 32993         SCIENCE                                                NaN
# 21050            TECH                                                NaN
# 22286   ENTERTAINMENT                                                NaN
# 113268       POLITICS  Republican Convention, Turkey, Garry Marshall:...

# %%
df_merged['category'].value_counts()
# Out:
# category
# POLITICS              61969
# ENTERTAINMENT         18495
# WORLDPOST             17535
# WELLNESS & HEALTH     13486
# SPORTS                 7837
# WORLD NEWS             7626
# BUSINESS               6727
# MINORITY VOICES        3640
# TRAVEL                 3640
# CRIME                  3363
# ENVIRONMENT            2927
# ARTS & CULTURE         2822
# PARENTING              2616
# FOOD & DRINK           2606
# MEDIA                  2384
# STYLE & BEAUTY         2136
# TECH                   1898
# COMEDY                 1892
# SCIENCE                1309
# IMPACT & GOOD NEWS     1307
# RELIGION               1178
# WOMEN & FIFTY           883
# EDUCATION               875
# MONEY                   621
# WEIRD NEWS              461
# HOME & LIVING           428
# U.S. NEWS               418
# WEDDINGS                325
# DIVORCE                 242
# Name: count, dtype: int64

# %%
df_merged['label'].value_counts()
# Out:
# label
# 1    100198
# 0     71448
# Name: count, dtype: int64

# %%
df_merged.to_csv("../datasets/CC_MC_WELF_merged.csv", index=False)
