# %%
import pandas as pd

# %%
r0 = pd.read_csv('test_pwws_results_gpu_0.csv')
r1 = pd.read_csv('test_pwws_results_gpu_1.csv')
r2 = pd.read_csv('test_pwws_results_gpu_2.csv')

# %%
# Merge the dataframes
print(r0.shape)
print(r1.shape)
print(r2.shape)
merged = pd.concat([r0, r1, r2], ignore_index=True)
print(merged.shape)
# Out:
# (266, 9)
# (266, 9)
# (268, 9)
# (800, 9)

# %%
merged.head()
# Out:
#                                        original_text  \
# 0  [[Noting]] the considerable likelihood that sh...
# 1  To the Editor:[[Trade]] Is [[Good]], but Voter...
# 2  [[In]] an [[alarming]] [[shift]] of mindset th...
# 3  Callum Patersons header for [[Hearts]] [[denie...
# 4  The Obamas: Weve Been [[Racially]] Mistreated ...
#
#                                       perturbed_text  original_score  \
# 0  [[note]] the considerable likelihood that she ...        0.000244
# 1  To the Editor:[[barter]] Is [[commodity]], but...        0.000092
# 2  [[indium]] an [[appal]] [[budge]] of mindset t...        0.000149
# 3  Callum Patersons header for [[mettle]] [[refus...        0.000067
# 4  The Obamas: Weve Been [[racially]] Mistreated ...        0.000190
#
#    perturbed_score  original_output  perturbed_output  ground_truth_output  \
# 0         0.617084                0                 1                    0
# 1         0.622915                1                 0                    1
# 2         0.518263                0                 1                    0
# 3         0.000161                1                 1                    1
# 4         0.604568                0                 1                    0
#
#    num_queries result_type
# 0         1145  Successful
# 1         2451  Successful
# 2         1848  Successful
# 3         4258      Failed
# 4         1400  Successful

# %%
merged['result_type'].value_counts()
# Out:
# result_type
# Successful    644
# Failed        156
# Name: count, dtype: int64

# %%
#how many of the column original output is the same as ground truth
def get_same_as_gt(row):
    if row['original_output'] == row['ground_truth_output']:
        return 1
    else:
        return 0
    
#apply the function to the dataframe
merged['same_as_gt'] = merged.apply(get_same_as_gt, axis=1)
merged['same_as_gt'].value_counts()
# Out:
# same_as_gt
# 1    800
# Name: count, dtype: int64

# %%
succes = merged[merged["result_type"] == "Successful"]

succes['ground_truth_output'].value_counts()
# Out:
# ground_truth_output
# 0    415
# 1    229
# Name: count, dtype: int64

# %%
merged.to_csv('test_pwws_results_all.csv', index=False)

# %%
train = pd.read_csv('pwws_results_all.csv')

# %%
train.shape
# Out:
# (3000, 10)

# %%
train['result_type'].value_counts()
# Out:
# result_type
# Successful    2349
# Failed         648
# Skipped          3
# Name: count, dtype: int64

# %%
successful = train[train["result_type"] == "Successful"]
successful['ground_truth_output'].value_counts()
# Out:
# ground_truth_output
# 0    1439
# 1     910
# Name: count, dtype: int64
