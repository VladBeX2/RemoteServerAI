# %%
import pandas as pd

# %%
r0 = pd.read_csv('val_pwws_results_gpu_0.csv')
r1 = pd.read_csv('val_pwws_results_gpu_1.csv')
r2 = pd.read_csv('val_pwws_results_gpu_2.csv')

# %%
# Merge the dataframes
print(r0.shape)
print(r1.shape)
print(r2.shape)
merged = pd.concat([r0, r1, r2], ignore_index=True)
print(merged.shape)
# Out:
# (266, 9)
# (266, 9)
# (268, 9)
# (800, 9)

# %%
merged.head()
# Out:
#                                        original_text  \
# 0  Egyptian [[Foreign]] Minster Ahmed Ali Abul Gh...
# 1  With a principle agreement in their [[grasp]] ...
# 2  [[Maria]] Sharapova [[returned]] to the tennis...
# 3  [[Norway]] [[City]] [[Declares]], We [[Have]] ...
# 4  Human clinical trials for a Taiwan-produced va...
#
#                                       perturbed_text  original_score  \
# 0  Egyptian [[extraneous]] Minster Ahmed Ali Abul...        0.000074
# 1  With a principle agreement in their [[range]] ...        0.000231
# 2  [[mare]] Sharapova [[devolve]] to the tennis [...        0.000061
# 3  [[Noreg]] [[city]] [[hold]], We [[feature]] Th...        0.000146
# 4  Human clinical trials for a Taiwan-produced va...        0.000077
#
#    perturbed_score  original_output  perturbed_output  ground_truth_output  \
# 0         0.830293                1                 0                    1
# 1         0.647406                0                 1                    0
# 2         0.000092                1                 1                    1
# 3         0.916526                0                 1                    0
# 4         0.543763                1                 0                    1
#
#    num_queries result_type
# 0          977  Successful
# 1         1379  Successful
# 2         3257      Failed
# 3         1063  Successful
# 4         2122  Successful

# %%
merged['result_type'].value_counts()
# Out:
# result_type
# Successful    644
# Failed        156
# Name: count, dtype: int64

# %%
#how many of the column original output is the same as ground truth
def get_same_as_gt(row):
    if row['original_output'] == row['ground_truth_output']:
        return 1
    else:
        return 0
    
#apply the function to the dataframe
merged['same_as_gt'] = merged.apply(get_same_as_gt, axis=1)
merged['same_as_gt'].value_counts()
# Out:
# same_as_gt
# 1    798
# 0      2
# Name: count, dtype: int64

# %%
succes = merged[merged["result_type"] == "Successful"]

succes['ground_truth_output'].value_counts()
# Out:
# ground_truth_output
# 0    405
# 1    218
# Name: count, dtype: int64

# %%
merged.to_csv('test_pwws_results_all.csv', index=False)
