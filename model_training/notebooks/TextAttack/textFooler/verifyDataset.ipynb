# %%
import pandas as pd

# %%
DATA_PATH  = "../../../datasets/Combined_Corpus/All_cleaned.csv"
MIN_WORDS = 100
MAX_WORDS = 200

# %%
df = pd.read_csv(DATA_PATH)

# %%
df["word_count"] = df["text"].str.split().apply(len)

# %%
mask = (df["language"] == "en") & (df["word_count"] < 400) & (df["word_count"] > 100) & (df['category'] == "MEDIA")
mask.sum()
#demo_df = df[mask].iloc[:10]
# Out:
# 9920

# %%
df.shape
# Out:
# (85270, 5)
