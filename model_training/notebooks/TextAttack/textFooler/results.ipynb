# %%
import pandas as pd

# %%
r0 = pd.read_csv('val_textfooler_results_gpu_0.csv')
r1 = pd.read_csv('val_textfooler_results_gpu_1.csv')
r2 = pd.read_csv('val_textfooler_results_gpu_2.csv')

# %%
# Merge the dataframes
print(r0.shape)
print(r1.shape)
print(r2.shape)
merged = pd.concat([r0, r1, r2], ignore_index=True)
print(merged.shape)
# Out:
# (266, 9)
# (266, 9)
# (268, 9)
# (800, 9)

# %%
merged.head()
# Out:
#                                        original_text  \
# 0  Muslims Everywhere Are Furious After DHL Makes...
# 1  Obama Admin Deports Christian Family [[For]] T...
# 2  [[For]] your chance to be crowned [[Guardian]]...
# 3  Having been talked by her boyfriend into seein...
# 4  If You Can See All The Faces In This [[Picture...
#
#                                       perturbed_text  original_score  \
# 0  Muslims Everywhere Are Furious After DHL Makes...        0.000159
# 1  Obama Admin Deports Christian Family [[With]] ...        0.000143
# 2  [[During]] your chance to be crowned [[Guardia...        0.000071
# 3  Having been talked by her boyfriend into seein...        0.000372
# 4  If You Can See All The Faces In This [[Cinemat...        0.000199
#
#    perturbed_score  original_output  perturbed_output  ground_truth_output  \
# 0         0.511956                0                 1                    0
# 1         0.742331                0                 1                    0
# 2         0.559920                1                 0                    1
# 3         0.989422                0                 1                    0
# 4         0.945095                0                 1                    0
#
#    num_queries result_type
# 0         3515  Successful
# 1         2310  Successful
# 2         1421  Successful
# 3          373  Successful
# 4          527  Successful

# %%
merged['result_type'].value_counts()
# Out:
# result_type
# Successful    681
# Failed        118
# Skipped         1
# Name: count, dtype: int64

# %%
#how many of the column original output is the same as ground truth
def get_same_as_gt(row):
    if row['original_output'] == row['ground_truth_output']:
        return 1
    else:
        return 0
    
#apply the function to the dataframe
merged['same_as_gt'] = merged.apply(get_same_as_gt, axis=1)
merged['same_as_gt'].value_counts()
# Out:
# same_as_gt
# 1    799
# 0      1
# Name: count, dtype: int64

# %%
succes = merged[merged["result_type"] == "Successful"]

succes['ground_truth_output'].value_counts()
# Out:
# ground_truth_output
# 0    439
# 1    242
# Name: count, dtype: int64

# %%
merged.to_csv('test_textfooler_results_all.csv', index=False)
